# %% [markdown]
# # Notebook of Summary, Visualization, and Illustration

# %% [markdown]
# ## Summary of the Paper

# %% [markdown]
# ## Overview of the Data

# %%
import numpy as np
import torch

from eICU_preprocessing.reader import eICUReader
from MIMIC_preprocessing.reader import MIMICReader
from eICU_preprocessing.run_all_preprocessing import eICU_path
from MIMIC_preprocessing.run_all_preprocessing import MIMIC_path

from trixi.experiment.pytorchexperiment import PytorchExperiment

# %%
torch.__version__

# %%
torch.cuda.is_available()

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
eICU_path
# Out:
# 'D:/datasets/eicu/'

# %%
eicu_reader = eICUReader(eICU_path + 'train', device = device)

# %% [markdown]
# ### Length of Stay Distribution (eICU)

# %%
plt.hist(eicu_reader.labels.actualiculos, label='actual', bins=1000)
plt.xlim([0,20])
# Out:
# (0.0, 20.0)

# %% [markdown]
# ## Overview of the Methods and Experiments

# %% [markdown]
# ### Code Examples

# %% [markdown]
# ## Summary of the Key Results

# %% [markdown]
# ## References
#  - link1
#  - link2
#  - ...

# %%
# !python -V
# Out:
# Python 3.6.8

# %%
# !python -m models.run_tpc --model_type pointwise_only
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "pointwise_only",
#     "n_epochs": 15,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
# ...

# %%
from trixi.util import Config

from models.run_tpc import run_tpc
from models.initialise_arguments import initialise_tpc_arguments

# %%
from eICU_preprocessing.split_train_test import create_folder
from torch.optim import Adam
from models.tpc_model import TempPointConv
from models.experiment_template import ExperimentTemplate
from models.initialise_arguments import initialise_tpc_arguments

# %%
c = initialise_tpc_arguments()
# Out:
# usage: ipykernel_launcher.py [-h] [--dataset DATASET] [-disable_cuda]
#                              [-intermediate_reporting]
#                              [--batch_size_test BATCH_SIZE_TEST]
#                              [-shuffle_train] [-save_results_csv]
#                              [--percentage_data PERCENTAGE_DATA] [--task TASK]
#                              [--mode MODE] [--loss LOSS] [-sum_losses]
#                              [-labs_only] [-no_mask] [-no_diag] [-no_labs]
#                              [-no_exp] [--alpha ALPHA]
#                              [--main_dropout_rate MAIN_DROPOUT_RATE]
#                              [--L2_regularisation L2_REGULARISATION]
#                              [--last_linear_size LAST_LINEAR_SIZE]
#                              [--diagnosis_size DIAGNOSIS_SIZE]
#                              [--batchnorm BATCHNORM] [--model_type MODEL_TYPE]
#                              [--n_epochs N_EPOCHS] [--batch_size BATCH_SIZE]
# ...

# %%
default_config = Config()

# %%
default_config["dataset"] = 'eICU'
default_config["disable_cuda"] = False
default_config["batch_size_test"] = 32
default_config["percentage_data"] = 100.0
default_config["task"] = 'LoS'
default_config["mode"] = 'train'
default_config["loss"] = 'mlse'
default_config["alpha"] = 100
default_config["main_dropout_rate"] = 0.45
default_config["L2_regularisation"] = 0.0
default_config["last_linear_size"] = 17
default_config["diagnosis_size"] = 64
default_config["batch_norm"] = 'mybatchnorm'

# %%
tpc_config = default_config
tpc_config['model_type'] = 'pointwise_only'
tpc_config['n_epochs'] = 15
tpc_config['batch_size'] = 32
tpc_config['n_layers'] = 9
tpc_config['kernel_size'] = 4
tpc_config['no_temp_kernels'] = 12
tpc_config['point_size'] = 13
tpc_config['learning_rate'] = 0.00226
tpc_config['temp_dropout_rate'] = 0.05

# %%
default_config = {
    'dataset': 'eICU',
    'batch_size_test': 32,
    'percentage_data': 100.0,
    'task': 'LoS',
    'mode': 'train',
    'loss': 'mlse',
    'alpha': 100,
    'main_dropout_rate': 0.45,
    'L2_regularisation': 0.0,
    'last_linear_size': 17,
    'diagnosis_size': 64,
    'batch_norm': 'mybatchnorm',
}

# %%
# TODO
c = tpc_config

c['temp_kernels'] = [c['no_temp_kernels']]*c['n_layers']
c['point_sizes'] = [c['point_size']]*c['n_layers']
if c['dataset'] == 'MIMIC':  # set no_diag to True if the dataset is MIMIC
    c['no_diag'] = True

# %%
run_tpc(c)
