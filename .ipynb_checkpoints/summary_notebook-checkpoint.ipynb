# %% [markdown]
# UIUC CS598 Deep Learning For Healthcare

# %% [markdown]
# # Notebook for Summary, Visualization, and Illustration

# %% [markdown]
#   **Kumar Harsh** and **Sewoong Lee**
#
# `{kumarha2, samuel27}@illinois.edu`

# %% [markdown]
# ## 1. Summary of the Paper

# %% [markdown]
# Prediction of in-patient **length of stay (LoS)** is an important and difficult task - as it accounts for about 90% of inter-patient variation in hospital costs in the US, and is also associated with more serious outcomes like infections and fatality. Prediction of good length of stay estimates promises various benefits:
#  - Increased accuracy of predictions, which can enable more sophisticated planning strategies.
#  - Reduced administrative burden on clinicians,freeing them up to focus on patient care.
#  - Improved patient experiences, as patients are more likely to be discharged on time and have a better understanding of their discharge date.
#
# However, there are many challenges in gathering the data required and developing models for making these predictions. Rocheteau et al. (2020) proposes a new model - Temporal Pointwise Convolution (TPC) - which aims to mitigate challenges with EHR data, such as data skew, missing data, and irregular sampling. The model claims to provide a significant performance benefit of 18-68% over LSTM networks and Transformers.

# %% [markdown]
# ## 2. Overview of the Data

# %%
import time
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from eICU_preprocessing.reader import eICUReader
from MIMIC_preprocessing.reader import MIMICReader
from eICU_preprocessing.run_all_preprocessing import eICU_path
from MIMIC_preprocessing.run_all_preprocessing import MIMIC_path
import json
import json5  # results-log.json has trailing comma in trixi, so we need json5

# %%
total_start = time.time()

# %%
# !python -V
torch.__version__, torch.cuda.is_available()
# Out:
# Python 3.6.8
# ('1.9.1+cu111', True)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
eICU_path, MIMIC_path
# Out:
# ('D:/datasets/eicu/', 'D:/datasets/mimic-iv-0.4/')

# %%
eicu_reader = eICUReader(eICU_path + 'train', device = device)
mimic_reader = MIMICReader(MIMIC_path + 'train', device = device)

# %% [markdown]
# ### 2.1. Length of Stay Distribution

# %% [markdown]
# #### 2.1.1. eICU

# %%
plt.hist(eicu_reader.labels.actualiculos, bins=1000)
plt.xlim([0,20])
print("Data Count: ", len(eicu_reader.labels.actualiculos))
plt.show()
# Out:
# Data Count:  102749

# %% [markdown]
# #### 2.1.2. MIMIC-IV

# %%
plt.hist(mimic_reader.labels.actualiculos, bins=1000)
plt.xlim([0,20])
print("Data Count: ", len(mimic_reader.labels.actualiculos))
plt.show()
# Out:
# Data Count:  48848

# %% [markdown]
# MIMIC-IV has less data than eICU, but overall shape is similar.

# %% [markdown]
# ## 3. Experiments

# %% [markdown]
# ### 3.1. Measuring MSLE for Each Model
# #### 3.1.1. Overview
# Validation MSLE (Mean Square Logarithmic Error)
#
# **Models**
#  - TPC
#  - LSTM
#  - Transformers

# %% [markdown]
# #### 3.1.2. Code Examples

# %% [markdown]
# **TPC Model Type**
#  - `tpc` : Temporal Pointwise Convolution
#  - `temp_only` : Temporal Convolution Only
#  - `pointwise_only` : Pointwise Convolution Only

# %%
# Test Parameter
N_EPOCH = 5

# %%
results_path = "\\result\\results.json"
results_log_path = "\\result\\results-log.json"
time_perf = {}

# %%
start = time.time()
# !python -m models.run_tpc --model_type pointwise_only --n_epochs {N_EPOCH}
end = time.time()
time_perf["pointwise_only"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "pointwise_only",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 2756658721,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (point): Linear(in_features=254, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (point): Linear(in_features=267, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (point): Linear(in_features=280, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (point): Linear(in_features=293, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (point): Linear(in_features=306, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (point): Linear(in_features=319, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (point): Linear(in_features=332, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (point): Linear(in_features=345, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=422, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=422, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[216684 120016  40688  22073  13284   8900   6256   4642  12394   5005]
#  [ 77595  71787  30236  18922  13861  10095   7759   6205  18801   7981]
#  [ 30662  37968  18905  13618  10577   8391   6542   5878  19659   9192]
#  [ 14334  20401  11635   8846   7672   6287   5338   4655  18102   9517]
#  [  7179  11445   7278   5898   5442   4712   4259   3742  16027   9560]
#  [  4115   7361   4922   4286   3968   3499   3148   2860  13406   9583]
#  [  2443   4574   3124   2751   2646   2686   2523   2342  11116   9255]
#  [  1531   3168   2230   2015   1978   1993   1895   1840   9078   8897]
#  [  3086   7517   5800   5030   4759   4773   5191   5250  31978  37812]
#  [  1748   3451   2599   2409   2505   2404   2526   2612  18311  33123]]
# Mean absolute deviation (MAD) = 3.749632103067048
# Mean squared error (MSE) = 72.59862285831915
# Mean absolute percentage error (MAPE) = 229.3835557418203
# Mean squared logarithmic error (MSLE) = 1.7891862642023657
# R^2 Score = -0.17705395766134924
# Cohen kappa score = 0.417739805944946
# Epoch: 4 | Validation Loss: 111.6805
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %%
start = time.time()
# !python -m models.run_tpc --model_type temp_only --n_epochs {N_EPOCH}
end = time.time()
time_perf["temp_only"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "temp_only",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 1100362536,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(3,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(6,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(9,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(12,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(15,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(18,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(21,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(24,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=1260, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=1260, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1082146  783887  150545   46816   18664    8735    4600    2441    4100
#      1069]
#  [ 393081  566186  164519   59517   25626   11993    6386    3676    6069
#      1398]
#  [ 137060  339106  152545   64622   29228   14455    8061    4793    8153
#      1970]
#  [  55178  192544  122541   60748   30520   16237    9339    5692   10512
#      2719]
#  [  27030  114940   90581   51197   28096   16019    9694    6242   11992
#      3485]
#  [  15058   74034   65422   42116   24694   14788    9361    5972   12558
#      4052]
#  [   9219   49816   49289   33848   20972   13090    8583    5693   12365
#      4565]
#  [   5835   34865   37985   27561   17574   11251    7609    5073   11560
#      4428]
#  [  13608   93355  110780   86704   59979   40845   27931   19669   47851
#     21104]
#  [   6791   49436   64008   54578   40880   28828   21050   15049   38113
#     18095]]
# Mean absolute deviation (MAD) = 2.65944168075722
# Mean squared error (MSE) = 35.19063078527829
# Mean absolute percentage error (MAPE) = 123.0103957178403
# Mean squared logarithmic error (MSLE) = 1.458717777430419
# R^2 Score = 0.04015974525826527
# Cohen kappa score = 0.34623651251880605
# Epoch: 0 | Train Loss: 91.7774
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[289190 124702  23624   7908   2977    955    370    106    110      0]
#  [ 91686 118065  32257  13374   4933   1736    642    288    241     20]
#  [ 22218  73865  34833  17960   7372   2820   1265    510    501     48]
#  [  7325  35542  27928  18072   9610   4255   1969   1015   1038     33]
#  [  2908  16944  19219  15208   9742   5461   2646   1485   1845     84]
#  [  1530   9834  12159  11981   8404   5679   3169   1786   2418    188]
#  [   995   5815   7387   8725   7260   4966   3254   2011   2772    275]
#  [   626   3962   4856   6611   5901   4573   3077   1750   2861    408]
#  [  1425   8460  12283  19079  20364  15772  10196   7288  13748   2581]
#  [   613   3910   7161  11100  14897  15570  13578  12047  27147   5173]
#  [   373   1550   3117   4813   6396   8525   9070   8176  24169   5499]]
# Mean absolute deviation (MAD) = 1.9640026882642179
# Mean squared error (MSE) = 49.27993676482161
# Mean absolute percentage error (MAPE) = 73.68873887777542
# Mean squared logarithmic error (MSLE) = 0.7788921639478559
# R^2 Score = 0.2010159102393022
# Cohen kappa score = 0.6184705451676762
# Epoch: 3 | Validation Loss: 48.6083
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1424868  558769   80394   22369    8381    3815    1798     978    1406
#       225]
#  [ 338744  646164  176741   43605   16590    7500    3616    1979    3017
#       495]
#  [  67984  308527  244740   76196   30146   13772    7081    4073    6387
#      1087]
#  [  20194  113860  177620   94419   44462   22294   12202    6966   11675
#      2338]
#  [   8232   49317   99170   79708   46968   27115   15953    9953   18621
#      4239]
#  [   4304   25443   56364   56484   40350   26259   17220   11400   23689
#      6542]
#  [   2463   15009   35742   38771   31407   22859   15712   11298   25471
#      8708]
#  [   1262    9541   24148   27846   23815   18254   13618    9921   24741
#     10595]
#  [   3214   22058   58558   72168   65981   54794   43684   34615  103244
#     63510]
#  [   1416    9432   28502   38658   37034   33570   28258   22985   77027
#     59946]]
# Mean absolute deviation (MAD) = 2.2338325391222713
# Mean squared error (MSE) = 31.956309644203834
# Mean absolute percentage error (MAPE) = 84.34179925317686
# Mean squared logarithmic error (MSLE) = 0.9179291355176135
# R^2 Score = 0.128377306543475
# Cohen kappa score = 0.5679637632830566
# Epoch: 4 | Train Loss: 57.7532
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[329850 100314  13218   4045   1580    610    215     71     39      0]
#  [ 66162 145893  36412   8922   3481   1349    621    274    128      0]
#  [ 10160  66174  55035  17820   7180   2739   1287    561    436      0]
#  [  2751  22773  34669  24457  12071   5429   2499   1076   1051     11]
#  [  1031   8212  15502  20360  14121   7833   4176   2109   2116     82]
#  [   517   4122   7904  12520  11879   8265   5225   2921   3650    145]
#  [   261   2085   4562   6968   8470   7201   5093   3298   5215    307]
#  [   168   1500   2752   4430   5634   5502   4731   3182   6239    487]
#  [   481   3259   5887   9037  13056  15084  14700  12150  30960   6582]
#  [   300   1232   2779   4247   5708   7122   8283   7803  26528   7686]]
# Mean absolute deviation (MAD) = 1.897466722055172
# Mean squared error (MSE) = 48.174769606531214
# Mean absolute percentage error (MAPE) = 69.09669777286186
# Mean squared logarithmic error (MSLE) = 0.715639367706865
# R^2 Score = 0.21893417543948013
# Cohen kappa score = 0.6442027255041001
# Epoch: 4 | Validation Loss: 44.6546
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %%
start = time.time()
# !python -m models.run_tpc --model_type tpc --n_epochs {N_EPOCH}
end = time.time()
time_perf["tpc"] = (end - start)
print(f"{(end - start)/60:.2f} min")

# %%
start = time.time()
# !python -m models.run_lstm --n_epochs {N_EPOCH}
end = time.time()
time_perf["lstm"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/LSTM",
#     "batch_size": 512,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "bidirectional": false,
#     "channelwise": false,
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "LSTM",
#     "hidden_size": 128,
#     "intermediate_reporting": false,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00129,
#     "loss": "msle",
#     "lstm_dropout_rate": 0.2,
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "n_epochs": 5,
#     "n_layers": 2,
#     "name": "LSTM",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "percentage_data": 100.0,
#     "save_results_csv": false,
#     "seed": 99799140,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS"
# }
# Experiment set up.
# BaseLSTM(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (lstm_dropout): Dropout(p=0.2, inplace=False)
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (empty_module): EmptyModule()
#   (lstm): LSTM(176, 128, num_layers=2, dropout=0.2)
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_los): Linear(in_features=257, out_features=17, bias=True)
#   (point_mort): Linear(in_features=257, out_features=17, bias=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[911000 929498 145140  54921  26235  13817   8088   4880   8119   1305]
#  [377647 573746 140187  64719  33777  18364  10813   6587  10960   1651]
#  [170205 340142 110153  57446  32215  18633  10990   6750  11712   1747]
#  [ 86111 211932  84844  48156  28205  16925  10379   6386  11210   1882]
#  [ 49047 139591  65064  39843  23923  14734   9210   5766  10384   1714]
#  [ 30414  96833  50823  32776  20354  12735   7958   5082   9406   1674]
#  [ 19568  69575  40975  27540  17182  11099   6970   4545   8444   1542]
#  [ 12735  51756  33084  22839  14800   9605   6135   4002   7450   1335]
#  [ 30763 147428 105469  78111  52461  34514  22874  15051  29447   5708]
#  [ 14675  76736  65292  52908  38310  26666  18118  12492  25935   5696]]
# Mean absolute deviation (MAD) = 2.8496282015033207
# Mean squared error (MSE) = 36.05800451474019
# Mean absolute percentage error (MAPE) = 142.06165101288454
# Mean squared logarithmic error (MSLE) = 1.745306804931676
# R^2 Score = 0.016501737349202905
# Cohen kappa score = 0.24153395572885894
# Epoch: 0 | Train Loss: 109.8169
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[209304 182533  32846  13634   6362   2955   1279    627    402      0]
#  [ 71671 118767  35289  19391  10393   4756   1883    668    424      0]
#  [ 29375  66473  27365  18049  11186   5451   2203    808    482      0]
#  [ 14516  38585  19072  15550  10222   5334   2075    818    615      0]
#  [  7704  23245  14668  12410   9201   4935   1960    823    596      0]
#  [  4546  16007  10933  10204   7404   4593   1971    844    646      0]
#  [  2989  10499   8311   8156   6457   3808   1824    858    558      0]
#  [  1962   7542   6723   6506   5583   3472   1594    761    482      0]
#  [  4320  19362  19823  23447  20565  12701   6410   2625   1943      0]
#  [  2055  10098  11392  14466  13977   9206   4766   3285   2443      0]]
# Mean absolute deviation (MAD) = 2.732814002815303
# Mean squared error (MSE) = 58.865284953851976
# Mean absolute percentage error (MAPE) = 128.04474224031944
# Mean squared logarithmic error (MSLE) = 1.5108987686796156
# R^2 Score = 0.04560701159560887
# Cohen kappa score = 0.2923259411221111
# Epoch: 3 | Validation Loss: 94.3022
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1018677  846260  131931   50817   23669   12625    6885    4045    6846
#      1248]
#  [ 369998  557818  153602   71453   36307   19485   10813    6582   10716
#      1677]
#  [ 153313  319716  125068   68511   37395   21228   12491    7498   12670
#      2103]
#  [  71187  191512   95466   57550   34299   20356   12194    7599   13505
#      2362]
#  [  37951  119545   72004   47702   29813   18136   11205    7276   13189
#      2455]
#  [  22254   78416   55007   39195   25589   15930    9968    6638   12522
#      2536]
#  [  13475   53706   42845   32634   21564   14113    9085    5964   11592
#      2462]
#  [   8128   37207   33507   27184   18881   12173    8075    5438   10760
#      2388]
#  [  17416   94945  100382   88603   65781   46173   31399   21183   44955
#     10989]
#  [   6655   38962   52941   54540   45529   34594   25378   18709   45575
#     13945]]
# Mean absolute deviation (MAD) = 2.6765029837485437
# Mean squared error (MSE) = 32.72665702011841
# Mean absolute percentage error (MAPE) = 126.34641273456799
# Mean squared logarithmic error (MSLE) = 1.488486506556453
# R^2 Score = 0.10736573599081534
# Cohen kappa score = 0.32683064142246
# Epoch: 4 | Train Loss: 93.6592
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[215743 174739  33835  13906   6323   2896   1353    658    489      0]
#  [ 74290 114898  36360  19307  10373   4725   1987    810    492      0]
#  [ 30759  64342  27679  18268  10894   5552   2370    925    603      0]
#  [ 15230  37104  19686  15537  10049   5228   2384    889    680      0]
#  [  8013  22513  14866  12600   8976   4882   2106    909    677      0]
#  [  4686  15557  11040  10292   7368   4500   2062    947    696      0]
#  [  3105  10130   8524   8057   6309   3884   1919    869    663      0]
#  [  2088   7288   6737   6522   5464   3521   1600    811    594      0]
#  [  4654  18842  20169  22606  20040  12969   6534   2974   2408      0]
#  [  2279  10028  11265  14282  13150   9148   5039   3198   3299      0]]
# Mean absolute deviation (MAD) = 2.7297436506815256
# Mean squared error (MSE) = 58.78479097827634
# Mean absolute percentage error (MAPE) = 127.09755739687427
# Mean squared logarithmic error (MSLE) = 1.5029021815968853
# R^2 Score = 0.04691207426469146
# Cohen kappa score = 0.2962212328258692
# Epoch: 4 | Validation Loss: 93.8035
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.
# 58.73 min

# %%
start = time.time()
# !python -m models.run_transformer --n_epochs {N_EPOCH}
end = time.time()
time_perf["transformer"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/Transformer",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "d_model": 16,
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "Transformer",
#     "feedforward_size": 256,
#     "intermediate_reporting": false,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00017,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "n_epochs": 5,
#     "n_heads": 2,
#     "n_layers": 6,
#     "name": "Transformer",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "percentage_data": 100.0,
#     "positional_encoding": false,
#     "save_results_csv": false,
#     "seed": 1825047038,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "trans_dropout_rate": 0
# }
# Experiment set up.
# Transformer(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (trans_dropout): Dropout(p=0, inplace=False)
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (empty_module): EmptyModule()
#   (transformer): TransformerEncoder(
#     (input_embedding): Conv1d(176, 16, kernel_size=(1,), stride=(1,))
#     (pos_encoder): PositionalEncoding()
#     (trans_encoder_layer): TransformerEncoderLayer(
#       (self_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#       )
#       (linear1): Linear(in_features=16, out_features=256, bias=True)
#       (dropout): Dropout(p=0, inplace=False)
#       (linear2): Linear(in_features=256, out_features=16, bias=True)
#       (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)63.19 min
#       (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (dropout1): Dropout(p=0, inplace=False)
#       (dropout2): Dropout(p=0, inplace=False)
#     )
#
#     (transformer_encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (1): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (2): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (3): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (4): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (5): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#       )
#     )
#   )
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_los): Linear(in_features=145, out_features=17, bias=True)
#   (point_mort): Linear(in_features=145, out_features=17, bias=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 828211 1016990  145801   54788   25765   13236    7213    4221    6180
#       598]
#  [ 342717  618642  140091   63101   32332   17300    9757    5631    8102
#       778]
#  [ 156496  365250  111621   56343   30021   16569    9478    5430    8051
#       734]
#  [  81276  227760   87096   47402   26350   14831    8423    4954    7267
#       671]
#  [  47441  151463   68014   38864   22327   12683    7213    4281    6401
#       589]
#  [  31023  105691   53582   31995   18907   10641    6356    3784    5593
#       483]
#  [  20681   77117   43536   26814   16091    9187    5414    3157    4955
#       488]
#  [  14006   57921   35602   22414   13434    8032    4779    2920    4260
#       373]
#  [  35454  169555  116709   78404   48354   28548   17146   10274   15882
#      1500]
#  [  19441   91856   76798   55751   35593   21720   13248    8044   13021
#      1356]]
# Mean absolute deviation (MAD) = 2.8941406716133904
# Mean squared error (MSE) = 37.35441097799165
# Mean absolute percentage error (MAPE) = 139.75962652934646
# Mean squared logarithmic error (MSLE) = 1.801875484015654
# R^2 Score = -0.018858331003327677
# Cohen kappa score = 0.19733640905761418
# Epoch: 0 | Train Loss: 113.3684
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[175047 213844  32560  13795   8095   4081   1678    605    237      0]
#  [ 62797 127828  31550  19091  12185   6309   2487    779    216      0]
#  [ 25867  72147  23709  16893  12530   6426   2650    921    249      0]
#  [ 12537  41807  17268  14356  11176   5920   2474    937    312      0]
#  [  6731  25513  12759  11651   9581   5681   2391    892    343      0]
#  [  4090  17151   9841   9276   8272   4994   2291    886    347      0]
#  [  2661  11420   7371   7402   7147   4425   1906    835    293      0]
#  [  1753   8332   5672   5990   6136   3878   1748    832    284      0]
#  [  3414  21663  17926  20987  21844  14117   6990   2870   1385      0]
#  [  1337  10781  10034  12824  15567  10801   5984   3074   1286      0]]
# Mean absolute deviation (MAD) = 2.756173808808221
# Mean squared error (MSE) = 58.8772050623316
# Mean absolute percentage error (MAPE) = 134.26959764827643
# Mean squared logarithmic error (MSLE) = 1.5677655392904903
# R^2 Score = 0.0454137488268499
# Cohen kappa score = 0.28145071747754913
# Epoch: 0 | Validation Loss: 97.8507
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1014936  842406  139738   52326   23649   12151    6860    3920    6124
#       893]
#  [ 367532  562818  156588   70971   35158   18723   10181    5974    9262
#      1244]
#  [ 150299  327867  127776   67793   35774   20044   11217    6757   10997
#      1469]
#  [  69294  197362   98005   57604   33122   19516   11223    6705   11478
#      1721]
#  [  36075  125466   73362   47329   29055   17570   10715    6484   11429
#      1791]
#  [  21570   82159   55946   39309   24780   15466    9758    5993   11214
#      1860]
#  [  13397   56026   43633   32719   21449   13701    8513    5632   10559
#      1811]
#  [   8373   38325   34738   27251   18394   11965    7713    5120    9896
#      1966]
#  [  20240   95784  103275   89716   65308   45075   30634   20962   41829
#      9003]
#  [   7891   40711   55784   57475   46721   34556   25419   18008   40103
#     10160]]
# Mean absolute deviation (MAD) = 2.681587407665286
# Mean squared error (MSE) = 33.253806593765226
# Mean absolute percentage error (MAPE) = 126.62986545801324
# Mean squared logarithmic error (MSLE) = 1.5038832012776673
# R^2 Score = 0.09298749468722867
# Cohen kappa score = 0.3174264272676317
# Epoch: 4 | Train Loss: 94.6201
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[223462 172115  32589  12857   5637   2140    844    174    124      0]
#  [ 78555 116333  36399  18944   8505   3182    935    245    144      0]
#  [ 31742  67485  28449  18369   9491   3941   1323    412    180      0]
#  [ 14764  39551  20979  16028   9182   4005   1572    471    235      0]
#  [  7553  24328  15399  13197   8394   4192   1708    474    297      0]
#  [  4411  16387  11363  10875   7354   4046   1821    551    340      0]
#  [  2784  10531   8579   9009   6379   3486   1697    607    388      0]
#  [  1838   7532   6700   7101   5517   3131   1774    642    390      0]
#  [  3947  18478  19635  22853  20870  13413   7205   2964   1830      1]
#  [  1784   8372   9889  13423  14489  10948   6373   3575   2835      0]]
# Mean absolute deviation (MAD) = 2.6763283146502346
# Mean squared error (MSE) = 58.15096166563922
# Mean absolute percentage error (MAPE) = 120.48939473658629
# Mean squared logarithmic error (MSLE) = 1.453075669112912
# R^2 Score = 0.05718845791424454
# Cohen kappa score = 0.31123320015417977
# Epoch: 4 | Validation Loss: 90.6926
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %% [markdown]
# #### 3.1.3. Results

# %%
with open("experiments_paths.json") as f: 
    experiments_paths = json.load(f)

with open(experiments_paths["tpc"] + results_path) as f: tpc_results = json.load(f)
with open(experiments_paths["temp_only"] + results_path) as f: temp_results = json.load(f)
with open(experiments_paths["pointwise_only"] + results_path) as f: pointwise_results = json.load(f)
with open(experiments_paths["LSTM"] + results_path) as f: lstm_results = json.load(f)
with open(experiments_paths["Transformer"] + results_path) as f: transformers_results = json.load(f)
    
with open(experiments_paths["tpc"] + results_log_path) as f: tpc_results_log = json5.load(f)

# %% [markdown]
# **MSLE (Mean Square Logarithmic Error)**

# %%
def add_human_baseline(plt, x_cnt):
    plt.hlines(3.82, -0.5, x_cnt-0.5, color='red', label="Clinicians (3.82 days)")
    plt.legend()

# %%
def plot_msle():
    measure = "val_mad"
    plt.bar(["TPC", "Temporal", "Pointwise", "LSTM", "Transformers"], 
            [tpc_results[measure], temp_results[measure], pointwise_results[measure], lstm_results[measure], transformers_results[measure]])
    plt.title("Average LoS Error")
    
    add_human_baseline(plt, x_cnt=5)
    plt.ylim([0,4.5])

    plt.show()

# %%
plot_msle()

# %% [markdown]
# **Time Performance Analysis**

# %%
plt.bar(["TPC", "Temporal", "Pointwise", "LSTM", "Transformers"], 
        np.array([time_perf["tpc"], time_perf["temp_only"], time_perf["pointwise_only"], time_perf["lstm"], time_perf["transformer"]])/60)
plt.title("Execution Time (min)")
# Out:
# Text(0.5, 1.0, 'Execution Time (min)')

# %% [markdown]
# ### 3.2. When Using Loss Function as MSE (Mean Square Error)
# #### 3.2.1. Overview
# Loss function = MSE
#  - Comparing to the results when loss function in MLSE
#
# **Models**
#  - TPC
#  - LSTM
#  - Transformers

# %% [markdown]
# #### 3.2.2. Code Examples

# %%
mse_time_perf = {}

# %%
start = time.time()
# !python -m models.run_tpc --model_type pointwise_only --n_epochs {N_EPOCH} --loss mse
end = time.time()
mse_time_perf["pointwise_only"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "mse",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "pointwise_only",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 1428369366,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (point): Linear(in_features=254, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (point): Linear(in_features=267, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (point): Linear(in_features=280, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (point): Linear(in_features=293, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (point): Linear(in_features=306, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (point): Linear(in_features=319, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (point): Linear(in_features=332, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (point): Linear(in_features=345, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=422, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=422, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 53120 791224 763401 271081 116415  52310  25467  12931  15688   1366]
#  [ 19945 365852 437662 198103 102222  52766  27068  14554  18716   1563]
#  [  8126 177610 250184 138584  81295  45394  24967  13763  18504   1566]
#  [  4134  96394 152695  99291  63841  37559  21392  12265  16976   1483]
#  [  2187  57612 100406  72964  49986  30876  18095  10574  15184   1392]
#  [  1364  37602  69364  55237  39763  25221  15373   9144  13757   1230]
#  [   927  25496  49960  42768  32404  21331  13223   7998  12123   1210]
#  [   544  17792  37087  33782  26658  17642  11367   6942  10736   1191]
#  [  1831  47309 105483 105181  87614  61666  40425  25696  41736   4885]
#  [  1313  24600  55499  62546  56529  43685  29969  20245  36744   5698]]
# Mean absolute deviation (MAD) = 3.036180441491763
# Mean squared error (MSE) = 33.76032146823551
# Mean absolute percentage error (MAPE) = 266.0844329003281
# Mean squared logarithmic error (MSLE) = 2.1725866351016125
# R^2 Score = 0.07917207406835691
# Cohen kappa score = 0.20739673231922806
# Epoch: 0 | Train Loss: 2124.0450
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  1491 159898 174084  61968  29999  14664   5680   1536    622      0]
#  [   231  61178  98897  44477  29020  19290   7411   2061    677      0]
#  [    63  25589  53090  29295  23345  18997   8023   2245    745      0]
#  [    29  12528  29494  19285  18156  16611   7771   2170    743      0]
#  [     0   6446  17389  13269  13802  14146   7614   2154    722      0]
#  [     0   3844  11755   9518  10588  11698   6835   2134    776      0]
#  [     0   2334   7506   6651   8413   9597   6000   2133    826      0]
#  [     5   1299   5498   4886   6532   8243   5460   1902    800      0]
#  [     0   2945  12353  14801  19987  27434  20970   9188   3518      0]
#  [     0    961   6516   7278  10551  15412  15388  10706   4871      5]]
# Mean absolute deviation (MAD) = 2.9408497344256266
# Mean squared error (MSE) = 55.62435626008523
# Mean absolute percentage error (MAPE) = 269.4524907468847
# Mean squared logarithmic error (MSLE) = 2.111841243158111
# R^2 Score = 0.09815274587132794
# Cohen kappa score = 0.2727394481105734
# Epoch: 0 | Validation Loss: 3469.5713
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[446182 652128 436426 247754 137770  82020  54905  20926  23462   1430]
#  [178522 317519 252135 170513 115229  83699  63201  25471  30355   1807]
#  [ 75833 158618 141959 109022  83985  70404  59875  25895  32436   1966]
#  [ 36222  85919  84843  71234  60322  55600  53117  24114  32460   2199]
#  [ 19451  50160  53343  48497  44117  44051  45024  21827  30717   2089]
#  [ 11417  30981  35295  33789  32970  34762  38312  19487  28936   2106]
#  [  7050  19930  23877  24390  25174  28403  32473  17209  26700   2234]
#  [  4285  12999  16527  17554  19393  22590  27743  15245  25256   2149]
#  [  7983  28190  40283  47053  53040  66213  93986  60917 112560  11601]
#  [  2244   9354  14606  18496  23141  31870  54058  45175 112338  25546]]
# Mean absolute deviation (MAD) = 2.8796721734195105
# Mean squared error (MSE) = 27.76646450877319
# Mean absolute percentage error (MAPE) = 253.02137161836606
# Mean squared logarithmic error (MSLE) = 2.0108977381082624
# R^2 Score = 0.24265721379090532
# Cohen kappa score = 0.3375295512559876
# Epoch: 4 | Train Loss: 1746.9422
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 68909 191255  94341  42465  21190  12493   9611   3495   5755    428]
#  [ 21583  88171  58969  32825  21202  14918  12373   4751   7718    732]
#  [  7777  41706  33808  21857  16442  13436  12228   4876   8481    781]
#  [  3391  21885  19701  13957  12093  11004  10973   4561   8368    854]
#  [  1779  11993  12362   9429   8823   8556   9248   4216   8315    821]
#  [  1040   7177   8535   7202   6446   6861   7897   3437   7673    880]
#  [   530   4547   5370   5077   4933   5424   6476   3010   7218    875]
#  [   295   2981   3720   3748   3899   4274   5462   2694   6698    854]
#  [   374   5258   9261   9786  11488  12924  18969  10191  28510   4435]
#  [   125   2187   3945   4715   5349   6607  10328   6034  24817   7581]]
# Mean absolute deviation (MAD) = 2.874088886395382
# Mean squared error (MSE) = 53.0645148103578
# Mean absolute percentage error (MAPE) = 240.050174776829
# Mean squared logarithmic error (MSLE) = 1.8987511963128785
# R^2 Score = 0.13965589552841495
# Cohen kappa score = 0.3618714856645797
# Epoch: 4 | Validation Loss: 3309.9741
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %%
start = time.time()
# !python -m models.run_tpc --model_type temp_only --n_epochs {N_EPOCH} --loss mse
end = time.time()
mse_time_perf["temp_only"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "mse",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "temp_only",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 822609598,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(3,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(6,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(9,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(12,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(15,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(18,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(21,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(1131, 1044, kernel_size=(4,), stride=(1,), dilation=(24,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=1260, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=1260, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 97598 776585 682798 297494 128005  57961  28069  14478  18352   1663]
#  [ 36156 383060 400855 204891 101161  51143  26409  14351  18799   1626]
#  [ 14532 194084 234873 140603  77735  42331  23206  13042  17885   1702]
#  [  6560 106510 147018 100170  60581  34766  20428  11681  16791   1525]
#  [  3195  63350  97759  73359  47623  29476  17454  10369  15158   1533]
#  [  1794  40465  67796  55223  38680  24481  15098   9169  13916   1433]
#  [  1104  27073  48637  42740  31504  20699  13153   8262  12804   1464]
#  [   643  18405  35570  33589  25821  17731  11327   7253  11980   1422]
#  [  1683  44005  94968 102264  86027  63177  43523  28933  50808   6438]
#  [  1347  21696  48986  59081  55141  43953  32297  23039  44474   6814]]
# Mean absolute deviation (MAD) = 3.0144531490365973
# Mean squared error (MSE) = 33.43922271647869
# Mean absolute percentage error (MAPE) = 267.2259901086665
# Mean squared logarithmic error (MSLE) = 2.15696927662650474.62 min
# R^2 Score = 0.0879301866911194
# Cohen kappa score = 0.22075223221642726
# Epoch: 0 | Train Loss: 2103.8419
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Epoch: 4 | Validation Loss: 3008.0509
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %%
start = time.time()
# !python -m models.run_tpc --model_type tpc --n_epochs {N_EPOCH} --loss mse
end = time.time()
mse_time_perf["tpc"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",88.30 min
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "mse",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "tpc",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 1243724639,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1300, 1200, kernel_size=(4,), stride=(1,), dilation=(3,), groups=100)
#       (bn_temp): MyBatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1298, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1469, 1356, kernel_size=(4,), stride=(1,), dilation=(6,), groups=113)
#       (bn_temp): MyBatchNorm1d(1356, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1454, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1638, 1512, kernel_size=(4,), stride=(1,), dilation=(9,), groups=126)
#       (bn_temp): MyBatchNorm1d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1610, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1807, 1668, kernel_size=(4,), stride=(1,), dilation=(12,), groups=139)
#       (bn_temp): MyBatchNorm1d(1668, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1766, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1976, 1824, kernel_size=(4,), stride=(1,), dilation=(15,), groups=152)
#       (bn_temp): MyBatchNorm1d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1922, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(2145, 1980, kernel_size=(4,), stride=(1,), dilation=(18,), groups=165)
#       (bn_temp): MyBatchNorm1d(1980, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2078, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(2314, 2136, kernel_size=(4,), stride=(1,), dilation=(21,), groups=178)
#       (bn_temp): MyBatchNorm1d(2136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2234, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(2483, 2292, kernel_size=(4,), stride=(1,), dilation=(24,), groups=191)
#       (bn_temp): MyBatchNorm1d(2292, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2390, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=2781, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=2781, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 34629 999140 636153 231133  98913  46449  23677  13023  18116   1770]
#  [ 15223 465807 385076 174204  88150  46930  25559  14523  21017   1962]
#  [  7639 227166 229396 124458  70082  40505  23563  14074  20930   2180]
#  [  4570 121299 144071  90586  56316  34073  20550  12632  19852   2081]
#  [  2990  70445  96193  67070  44548  28884  17840  11199  18168   1939]
#  [  2186  44567  65524  51131  36248  24359  15384   9962  16745   1949]
#  [  1527  29014  47235  39515  29770  20208  13735   8764  15655   2017]
#  [  1040  19206  33804  31479  24836  17532  11806   7975  14053   2010]
#  [  2702  43799  90119  95087  82003  62381  44713  31317  60806   8899]
#  [  1939  20933  45055  53257  51705  43727  33956  24866  52646   8744]]
# Mean absolute deviation (MAD) = 2.95737843237433
# Mean squared error (MSE) = 32.87923472377771
# Mean absolute percentage error (MAPE) = 255.3587628232331
# Mean squared logarithmic error (MSLE) = 2.095850485422919
# R^2 Score = 0.10320411061837353
# Cohen kappa score = 0.24864849555557866
# Epoch: 0 | Train Loss: 2068.6103
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[   545 156100 190584  57053  24734  10696   5017   2489   2724      0]
#  [    28  61304 109727  42495  23870  12704   6617   3438   3058      1]
#  [     0  24140  61878  28616  19423  12255   7227   4129   3724      0]
#  [     0  10781  35220  19547  15305  10798   6860   4497   3779      0]
#  [     0   4987  21159  13821  11477   9183   6596   4375   3944      0]
#  [     0   2756  14127   9568   8924   7912   5583   4047   4231      0]
#  [     0   1710   8638   6397   7116   6473   4987   3803   4336      0]
#  [     0    936   5812   4812   5309   5217   4654   3717   4167      1]
#  [     0   1458  10997  12824  17241  17919  17059  14279  19419      0]
#  [     0    366   4410   5952   8149  10779  11481  10330  20207     14]]
# Mean absolute deviation (MAD) = 2.850832772402817
# Mean squared error (MSE) = 53.56820687501417
# Mean absolute percentage error (MAPE) = 269.0713438936618
# Mean squared logarithmic error (MSLE) = 2.082213306020609
# R^2 Score = 0.13148944946092656
# Cohen kappa score = 0.32426583293788536
# Epoch: 0 | Validation Loss: 3341.4361
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[957258 462700 269176 165293  99696  54014  30156  44883  18634   1193]
#  [416196 279935 186932 123956  82123  50737  31058  42544  23643   1327]
#  [177465 162412 123676  89291  64274  43288  29422  41305  27072   1788]
#  [ 74009  93657  82259  66007  50782  37990  28200  41281  29765   2080]
#  [ 30444  51307  52963  47985  40575  33036  26233  41137  33049   2547]
#  [ 13060  26655  32419  33212  30743  27688  24394  40321  36500   3063]
#  [  6250  13964  19381  21800  21845  21204  21328  38345  39737   3586]
#  [  3048   7646  11220  13572  15112  15942  17216  34690  41255   4040]
#  [  5271  12390  19423  25399  31120  36036  44099 114308 202586  31194]
#  [  1639   3967   6120   8407  10533  13440  17966  61262 160787  52707]]
# Mean absolute deviation (MAD) = 2.5248744055792076
# Mean squared error (MSE) = 23.770257087211274
# Mean absolute percentage error (MAPE) = 198.3585371516995
# Mean squared logarithmic error (MSLE) = 1.9518151154753831
# R^2 Score = 0.35165556545209364
# Cohen kappa score = 0.47167893681363837
# Epoch: 4 | Train Loss: 1495.5174
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[219326 111991  50139  24281  13251   7615   5739   6587   9322   1691]
#  [ 84340  72335  38991  20853  12060   7593   5663   7473  11691   2243]
#  [ 28727  41827  28082  16706   9850   7114   5291   7525  13653   2617]
#  [  8458  22154  18761  12709   8455   6023   4945   6968  15145   3169]
#  [  2386  10069  11535   9220   6855   5336   4351   6260  15806   3724]
#  [   792   4668   6681   6328   4975   4509   3850   5466  15540   4339]
#  [   310   1990   3511   3778   3390   3261   3093   4469  14585   5073]
#  [   202   1031   2024   2011   2192   2134   2288   3742  13459   5542]
#  [   344   1321   2622   3414   3939   4327   4419   9925  48637  32248]
#  [   216    593    686    983   1225   1490   1740   3931  27691  33133]]
# Mean absolute deviation (MAD) = 2.79983348687655
# Mean squared error (MSE) = 52.40720536956774
# Mean absolute percentage error (MAPE) = 198.19302790361672
# Mean squared logarithmic error (MSLE) = 1.609175377956211
# R^2 Score = 0.1503129665337425
# Cohen kappa score = 0.5203589955547037
# Epoch: 4 | Validation Loss: 3269.6431
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %%
start = time.time()
# !python -m models.run_lstm --n_epochs {N_EPOCH} --loss mse
end = time.time()
mse_time_perf["lstm"] = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:59.29 min
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#
#     "base_dir": "models/experiments/eICU/LoS/LSTM",
#     "batch_size": 512,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "bidirectional": false,
#     "channelwise": false,
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "LSTM",
#     "hidden_size": 128,
#     "intermediate_reporting": false,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00129,
#     "loss": "mse",
#     "lstm_dropout_rate": 0.2,
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "n_epochs": 5,
#     "n_layers": 2,
#     "name": "LSTM",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "percentage_data": 100.0,
#     "save_results_csv": false,
#     "seed": 310852844,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS"
# }
# Experiment set up.
# BaseLSTM(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (lstm_dropout): Dropout(p=0.2, inplace=False)
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (empty_module): EmptyModule()
#   (lstm): LSTM(176, 128, num_layers=2, dropout=0.2)
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_los): Linear(in_features=257, out_features=17, bias=True)
#   (point_mort): Linear(in_features=257, out_features=17, bias=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 205748 1109681  480151  163725   67025   32067   17132    9748   15501
#      2225]
#  [  95030  576775  305099  125732   58735   30289   17182   10086   16995
#      2528]
#  [  47684  313468  193764   90708   46331   25592   15122    9218   15586
#      2520]
#  [  27433  186271  130881   67187   36371   20956   12545    7931   14191
#      2264]
#  [  17605  120265   92264   51215   28996   17091   10416    6843   12392
#      2189]
#  [  12175   82772   68243   40018   23503   14124    8859    5672   10831
#      1858]
#  [   8626   59828   52180   31990   19438   11821    7495    4837    9534
#      1691]
#  [   6263   44606   40839   25830   15806    9867    6438    4303    8205
#      1584]
#  [  18086  129058  126954   84443   54075   34716   22791   15109   30544
#      6050]
#  [  12195   70496   75406   54681   37593   25325   17125   12052   26014
#      5941]]
# Mean absolute deviation (MAD) = 3.052126254727616
# Mean squared error (MSE) = 36.683394382963044
# Mean absolute percentage error (MAPE) = 219.55491207265365
# Mean squared logarithmic error (MSLE) = 2.1054507129593514
# R^2 Score = -0.0005560520973859617
# Cohen kappa score = 0.16611297743828113
# Epoch: 0 | Train Loss: 2307.1859
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  2165 233761 153778  39830  13675   4829   1307    413    184      0]
#  [   458 104076  95994  38017  16323   6107   1659    444    164      0]
#  [   174  49055  57754  30580  15382   6103   1670    552    122      0]
#  [    72  26166  35684  23403  13566   5576   1686    496    138      0]
#  [    73  14725  23523  18043  11747   5219   1572    501    139      0]
#  [    31   9365  16639  14512   9900   4578   1526    464    133      0]
#  [    20   5816  11805  11331   8432   3985   1417    537    117      0]
#  [    40   3812   8742   9236   7242   3749   1270    419    115      0]
#  [     3   8062  24021  31582  27173  13291   4984   1384    696      0]
#  [     8   3841  11971  19148  17945  10793   5532   1470    980      0]]
# Mean absolute deviation (MAD) = 2.9005798132083873
# Mean squared error (MSE) = 58.41627827659112
# Mean absolute percentage error (MAPE) = 224.87768959260913
# Mean squared logarithmic error (MSLE) = 1.9830443348382416
# R^2 Score = 0.0528868340726506
# Cohen kappa score = 0.21041293033258857
# Epoch: 0 | Validation Loss: 3643.8181
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [
print(f"{(end - start)/60:.2f} min")
# Out:
#     11392]]
# Mean absolute deviation (MAD) = 2.9547580852464845
# Mean squared error (MSE) = 33.72361569506986
# Mean absolute percentage error (MAPE) = 228.55594746857335
# Mean squared logarithmic error (MSLE) = 2.0066092884338387
# R^2 Score = 0.08017324051179997
# Cohen kappa score = 0.22610901646351123
# Epoch: 2 | Train Loss: 2121.0500
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  6765 257430 125424  36340  15118   5874   1935    662    394      0]
#  [  1405 114496  81156  35916  18838   7566   2537    869    459      0]
#  [   445  53643  49031  29263  16726   7965   2812    954    553      0]
#  [   308  27872  30571  22035  14554   7076   2707    969    695      0]
#  [   130  15489  19942  16540  12679   6691   2441    951    679      0]
#  [    35   9989  13756  13194  10565   5651   2456    832    670      0]
#  [    26   6219   9521  10603   8445   4840   2298    887    621      0]
#  [    28   4142   7157   8111   7255   4555   2043    788    540      6]
#  [    17   8736  19678  27102  25994  17057   7344   3582   1686      0]
#  [     0   4459   9919  14920  16802  12590   7173   3237   2588      0]]
# Mean absolute deviation (MAD) = 2.852373426525234
# Mean squared error (MSE) = 57.39649771632963
# Mean absolute percentage error (MAPE) = 217.40155749523763
# Mean squared logarithmic error (MSLE) = 1.9169411828451355
# R^2 Score = 0.06942071167449482
# Cohen kappa score = 0.24536140437292087
# Epoch: 2 | Validation Loss: 3580.1423
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 129398 1092014  569812  165651   66658   32800   17661   10024   16491
#      2494]
#  [  44688  527457  365942  141087   67761   36353   20326   12243   19780
#      2814]
#  [  16815  264499  228141  106217   56871   32729   19188   11966   20356
#      3211]
#  [   7707  146248  148702   79892   45935   27600   17065   10735   19097
#      3049]
#  [   4008   88089  101962   61061   36921   22919   14655    9293   17538
#      2830]
#  [   2273   57026   72814   47717   30315   19407   12518    8071   15228
#      2686]
#  [   1356   38357   54750   37991   25060   16132   10681    6897   13724
#      2492]
#  [    787   26575   41357   30715   20838   13782    9137    6081   12099
#      2370]
#  [   1643   67215  121045   97971   70590   48729   33757   23351   47402
#     10123]
#  [    546   27420   60248   57719   47133   36141   26649   19431   47356
#     14185]]
# Mean absolute deviation (MAD) = 2.926274920300227
# Mean squared error (MSE) = 32.773908986671024
# Mean absolute percentage error (MAPE) = 227.68767824632206
# Mean squared logarithmic error (MSLE) = 1.9793381931087963
# R^2 Score = 0.10607691738765801
# Cohen kappa score = 0.24235251977914518
# Epoch: 3 | Train Loss: 2061.3562
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  7781 258533 120182  34320  16151   7640   3342   1145    832     16]
#  [  1768 113503  77838  33572  20037   9778   4212   1632    879     23]
#  [   437  53116  46446  26170  17816   9906   4478   1823   1176     24]
#  [   262  27498  28619  19381  14728   8862   4422   1774   1206     35]
#  [   127  15099  18583  14343  12335   8051   4246   1569   1155     34]
#  [    52   9481  12894  11222  10101   7031   3594   1573   1176     24]
#  [    32   6173   8703   8687   8323   5759   2946   1644   1160     33]
#  [    51   4106   6551   6641   6814   5014   3006   1324   1085     33]
#  [    37   8525  18189  21219  24157  18469  10896   5369   4299     36]
#  [     0   4396   8542  11618  14743  13168   8654   4977   5582      8]]
# Mean absolute deviation (MAD) = 2.846479839904013
# Mean squared error (MSE) = 56.55830814452718
# Mean absolute percentage error (MAPE) = 221.7612248246906
# Mean squared logarithmic error (MSLE) = 1.918012924645265
# R^2 Score = 0.08301042335106401
# Cohen kappa score = 0.2687180690980827
# Epoch: 3 | Validation Loss: 3527.8720
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  97504 1102478  596575  162961   64847   31592   17518   10144   16805
#      2579]
#  [  34234  525137  381887  138629   66541   35520   20539   12323   20472
#      3169]
#  [  12756  259950  237022  105821   56268   32605   19321   12003   20940
#      3307]
#  [   5677  142239  153679   79332   46112   27844   17326   10787   19703
#      3331]
#  [   2888   84809  105175   60747   37196   22788   14911    9690   17857
#      3215]
#  [   1608   54637   74389   47363   30509   19333   12668    8457   16062
#      3029]
#  [    954   36079   55286   37945   25103   16629   11084    7272   14371
#      2717]
#  [    577   24643   41566   30609   20926   14149    9339    6390   12925
#      2617]
#  [   1204   60948  118891   97292   71273   50477   35086   24256   51162
#     11237]
#  [    226   22741   55172   55442   47262   37060   27884   20749   52213
#     18079]]
# Mean absolute deviation (MAD) = 2.9080852053052357
# Mean squared error (MSE) = 31.6445884479175
# Mean absolute percentage error (MAPE) = 230.91764499374702
# Mean squared logarithmic error (MSLE) = 1.9799322714239056
# R^2 Score = 0.13687964213039627
# Cohen kappa score = 0.25227284637356984
# Epoch: 4 | Train Loss: 1990.3856
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  4572 237963 139826  35609  16143   8369   4016   1646   1651    147]
#  [  1088 102763  86871  33426  19224  10517   5193   2143   1832    185]
#  [   295  47716  50375  26055  17121  10128   5202   2291   1991    218]
#  [   101  24505  30659  19074  14268   8746   4922   2267   2043    202]
#  [    32  13667  19299  14058  11487   7988   4560   2221   2035    195]
#  [     0   8434  13478  10621   9632   6848   3965   1972   1995    203]
#  [     0   5590   9026   8206   7812   5511   3374   1918   1815    208]
#  [     0   3737   6489   6461   6488   4563   3257   1766   1711    153]
#  [     0   6733  19533  19849  22246  17459  11688   6660   6769    259]
#  [     0   3485   9493  10411  12662  12591   9463   4808   8177    598]]
# Mean absolute deviation (MAD) = 2.8822173032256506
# Mean squared error (MSE) = 56.28538602432608
# Mean absolute percentage error (MAPE) = 233.4173333094086
# Mean squared logarithmic error (MSLE) = 1.9675098696028839
# R^2 Score = 0.08743535662208435
# Cohen kappa score = 0.27133002439196807
# Epoch: 4 | Validation Loss: 3510.8535
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/Transformer",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "d_model": 16,
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "Transformer",
#     "feedforward_size": 256,
#     "intermediate_reporting": false,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00017,
#     "loss": "mse",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "n_epochs": 5,
#     "n_heads": 2,
#     "n_layers": 6,
#     "name": "Transformer",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "percentage_data": 100.0,
#     "positional_encoding": false,
#     "save_results_csv": false,
#     "seed": 1029996546,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "trans_dropout_rate": 0
# }
# Experiment set up.
# Transformer(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (trans_dropout): Dropout(p=0, inplace=False)
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (empty_module): EmptyModule()
#   (transformer): TransformerEncoder(
#     (input_embedding): Conv1d(176, 16, kernel_size=(1,), stride=(1,))
#     (pos_encoder): PositionalEncoding()
#     (trans_encoder_layer): TransformerEncoderLayer(
#       (self_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#       )
#       (linear1): Linear(in_features=16, out_features=256, bias=True)
#       (dropout): Dropout(p=0, inplace=False)
#       (linear2): Linear(in_features=256, out_features=16, bias=True)
#       (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (dropout1): Dropout(p=0, inplace=False)
#       (dropout2): Dropout(p=0, inplace=False)
#     )
#     (transformer_encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (1): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (2): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (3): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (4): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#         (5): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#       )
#     )
#   )
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_los): Linear(in_features=145, out_features=17, bias=True)
#   (point_mort): Linear(in_features=145, out_features=17, bias=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[ 226438 1046324  486761  181132   75512   36291   19808   11307   17287
#      2143]
#  [ 106307  552855  302271  131425   62386   32926   18558   11001   18403
#      2319]
#  [  53021  304398  189992   93282   48093   26725   15915    9812   16639
#      2116]
#  [  30174  182833  127011   68087   37576   21773   13709    8416   14547
#      1904]
#  [  18478  120107   89860   51331   29605   17641   11034    7080   12451
#      1689]
#  [  12399   82893   66792   40129   23909   14746    9157    5883   10632
#      1515]
#  [   8590   60282   51318   32016   19670   12164    7747    5038    9293
#      1322]
#  [   6014   45090   40130   26049   16184   10173    6495    4321    8132
#      1153]
#  [  15238  130521  126107   85776   55383   35969   23555   15404   29432
#      4441]
#  [   9052   72524   75908   56179   38367   25852   17706   12187   24801
#      4252]]
# Mean absolute deviation (MAD) = 3.075580264977639
# Mean squared error (MSE) = 36.80209448445616
# Mean absolute percentage error (MAPE) = 224.29345438828784
# Mean squared logarithmic error (MSLE) = 2.125237439880941
# R^2 Score = -0.003793650660202319
# Cohen kappa score = 0.15800434872860036
# Epoch: 0 | Train Loss: 2315.4191
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  4965 237493 140494  38024  13442   6769   4205   2271   2259     20]
#  [  1517 106273  89629  33494  14864   7914   4452   2569   2508     22]
#  [   690  50774  53042  25272  13659   8171   4598   2537   2623     26]
#  [   278  27161  32189  18897  11600   7098   4495   2474   2562     33]
#  [   108  15334  20715  14371   9232   6395   4372   2417   2572     26]
#  [    33   9906  14337  11557   7278   5334   3860   2171   2642     30]
#  [    14   5942  10385   8903   5877   4544   3379   2045   2339     32]
#  [    15   3896   7935   6696   4796   4119   3069   1994   2096      9]
#  [    34   8074  22308  21560  17890  14263  10776   7006   9275     10]
#  [    12   4087  10385  12054  10725   9957   8064   6702   9268    434]]
# Mean absolute deviation (MAD) = 2.8782999469368846
# Mean squared error (MSE) = 56.40079977201068
# Mean absolute percentage error (MAPE) = 231.2066279706673
# Mean squared logarithmic error (MSLE) = 1.9713462347882758
# R^2 Score = 0.08556413368241778
# Cohen kappa score = 0.2654370642779401
# Epoch: 0 | Validation Loss: 3518.0644
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[  90672 1074695  578224  195115   77740   36424   19587   11194   17354
#      1998]
#  [  35027  530926  357439  151293   71195   37510   20849   12322   19492
#      2398]
#  [  14913  273870  219936  109313   57582   32380   18976   11468   19147
#      2408]
#  [   7289  155744  142929   80422   45680   27085   16382   10375   17687
#      2437]
#  [   3995   96025   98502   60993   36533   22149   14020    8877   15866
#      2316]
#  [   2366   63183   71577   47018   29523   18465   12102    7586   14145
#      2090]
#  [   1454   43386   53673   37812   24282   15863   10044    6575   12285
#      2066]
#  [    808   30755   40753   30288   20451   13332    8615    5933   10954
#  [    286   23553   37943   31148   22297   15382   10280    6935   13483
#      2434]
#  [    570   54614  106606   97227   75484   54797   38533   26374   55956
#     11665]
#  [    184   20130   49509   53546   47342   38272   29201   22247   57274
#     19123]]
# Mean absolute deviation (MAD) = 2.8905579273437296
# Mean squared error (MSE) = 31.65442024737056
# Mean absolute percentage error (MAPE) = 233.3660210553702
# Mean squared logarithmic error (MSLE) = 1.976988188808784
# R^2 Score = 0.13661147538598128
# Cohen kappa score = 0.2611802602094292
# Epoch: 4 | Train Loss: 1991.5576
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[   765 216596 141955  47689  19819  10491   5554   3123   3736    214]
#  [   195  93900  82198  38320  21302  12097   6770   3826   4446    188]
#  [    52  42812  46683  26676  17884  11538   6728   3974   4845    200]
#  [    21  21997  26824  18714  14337   9604   6445   3797   4765    283]
#  [     4  11707  16688  13199  11714   8134   5613   3529   4647    307]
#  [     0   7210  11251   9834   9223   6956   4751   3264   4326    333]
#  [     0   4276   7664   7193   7346   5679   3927   2983   4050    342]
#  [     0   2755   5301   5780   5600   4786   3514   2509   4060    320]
#  [     0   4586  13521  16840  17843  16966  12870   8940  18483   1147]
#  [     0   1541   5886   7645   9911   9540   8804   7727  18059   2575]]
# Mean absolute deviation (MAD) = 2.884910111672524
# Mean squared error (MSE) = 54.17164787412311
# Mean absolute percentage error (MAPE) = 253.51959716739793
# Mean squared logarithmic error (MSLE) = 2.0188168412248406
# R^2 Score = 0.12170575676468265
# Cohen kappa score = 0.3080863128108239
# Epoch: 4 | Validation Loss: 3379.0228
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.
# 63.92 min

# %% [markdown]
# #### 3.2.3. Results

# %%
with open("experiments_paths.json") as f: 
    experiments_paths = json.load(f)

results_path = "\\result\\results.json"
with open(experiments_paths["tpc"] + results_path) as f: tpc_mse_results = json.load(f)
with open(experiments_paths["temp_only"] + results_path) as f: temp_mse_results = json.load(f)
with open(experiments_paths["pointwise_only"] + results_path) as f: pointwise_mse_results = json.load(f)
with open(experiments_paths["LSTM"] + results_path) as f: lstm_mse_results = json.load(f)
with open(experiments_paths["Transformer"] + results_path) as f: transformers_mse_results = json.load(f)

# %% [markdown]
# **MSLE**

# %%
def msle_mle_comp():
    measure = "val_mad"

    df = pd.DataFrame(
        {
            "Loss Func: MSE": [tpc_mse_results[measure], temp_mse_results[measure], pointwise_mse_results[measure], lstm_mse_results[measure], transformers_mse_results[measure]],
            "Loss Func: MSLE": [tpc_results[measure], temp_results[measure], pointwise_results[measure], lstm_results[measure], transformers_results[measure]]
        },
        index=["TPC", "Temporal", "Pointwise", "LSTM", "Transformers"]
    )

    df.plot.bar(title="Average LoS Error")
    add_human_baseline(plt, x_cnt=5)
    plt.ylim([0,5.5])

    plt.show()

# %%
msle_mle_comp()

# %% [markdown]
# **MSE**

# %% [markdown]
# **Time Performance Analysis**

# %%
df = pd.DataFrame(
    {
        "Loss Func: MSE": np.array([mse_time_perf["tpc"], mse_time_perf["temp_only"], mse_time_perf["pointwise_only"], mse_time_perf["lstm"], mse_time_perf["transformer"]])/60,
        "Loss Func: MSLE": np.array([time_perf["tpc"], time_perf["temp_only"], time_perf["pointwise_only"], time_perf["lstm"], time_perf["transformer"]])/60
    },
    index=["TPC", "Temporal", "Pointwise", "LSTM", "Transformers"]
)

df.plot.bar(title="Execution Time (min)")
# Out:
# <AxesSubplot:title={'center':'Execution Time (min)'}>

# %% [markdown]
# ### 3.3. When No Skip Connections
# #### 3.3.1. Overview
# > We propagate skip connections [20] to allow each layer to see the original data and the pointwise outputs from previous layers. This helps the network to cope with sparsely sampled data.
#
# **Models**
#  - TPC
#  - TPC (no_skip_connections)

# %% [markdown]
# #### 3.3.2. Code Examples

# %%
start = time.time()
# !python -m models.run_tpc --model_type tpc --n_epochs {N_EPOCH} -no_skip_connections
end = time.time()
no_skip_time = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
# 74.75 min
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "tpc",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": true,
#     "no_temp_kernels": 12,
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 3605886173,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(3,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(6,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(9,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(12,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(15,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(18,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(21,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(1044, 1044, kernel_size=(4,), stride=(1,), dilation=(24,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=13, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=1186, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=1186, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1024831  823480  156363   51224   21297   10247    5620    3143    5585
#      1213]
#  [ 397635  556735  159273   62225   27597   13874    7489    4319    7514
#      1790]
#  [ 157877  335747  136499   60617   29065   15128    8560    4947    9228
#      2325]
#  [  69770  200893  108706   54869   28399   15548    9163    5530   10427
#      2725]
#  [  35342  124200   82523   47172   26032   15085    8832    5667   11233
#      3190]
#  [  20416   80699   62629   38810   22757   13598    8637    5561   11363
#      3585]
#  [  12745   54091   48516   31861   19713   12286    7994    5346   11323
#      3565]
#  [   7674   38523   37638   26370   16756   10700    7084    4812   10432
#      3752]
#  [  17543   98929  110811   85742   59268   40362   27694   19266   44538
#     17673]
#  [   8403   49887   62754   54765   41150   29411   20836   15223   37689
#     16710]]
# Mean absolute deviation (MAD) = 2.711633600955866
# Mean squared error (MSE) = 35.22152231590633
# Mean absolute percentage error (MAPE) = 130.03700150610408
# Mean squared logarithmic error (MSLE) = 1.5413811662299972
# R^2 Score = 0.0393171648905446
# Cohen kappa score = 0.31960536134391304
# Epoch: 0 | Train Loss: 96.9789
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[247197 150158  33392  11544   4113   1808    835    386    492     17]
#  [ 78915 116275  39662  15764   6789   2882   1500    700    719     36]
#  [ 23547  67329  35234  17999   8664   4305   2262    871   1093     88]
#  [  8537  34126  25921  17052   9849   5186   2686   1384   1900    146]
#  [  3558  17556  17266  14057   9510   5683   3051   1928   2709    224]
#  [  2051  10035  12034  10677   8116   5020   3409   1991   3437    378]
#  [  1100   6060   7822   7861   6472   4834   2992   1974   3841    504]
#  [   639   4258   5435   5630   5231   3863   2772   2133   4033    631]
#  [  1334   9092  13136  16545  16633  13929  10539   7190  18672   4126]
#  [   565   3750   6524   8051   9801   9108   8011   6563  15645   3670]]
# Mean absolute deviation (MAD) = 2.3912456120666192
# Mean squared error (MSE) = 53.484343321218766
# Mean absolute percentage error (MAPE) = 114.82243822079761
# Mean squared logarithmic error (MSLE) = 1.2291064108639578
# R^2 Score = 0.1328491436811745
# Cohen kappa score = 0.46435856413670196
# Epoch: 0 | Validation Loss: 76.7112
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1229563  668074  129763   41328   16321    7572    3898    2222    3559
#       703]
#  [ 413324  550257  161183   58692   25215   12311    6469    3745    6057
#      1198]
#  [ 125732  327681  161965   69430   32219   16606    9125    5380    9671
#      2184]
#  [  45004  167460  132417   69415   36242   20087   11466    7149   13368
#      3422]
#  [  19885   89002   93543   59386   34383   20773   12593    8130   16619
#      4962]
#  [  10737   51952   64231   47103   29808   19114   12483    8255   18264
#      6108]
#  [   6212   32707   45703   36968   25291   16530   11389    7810   18125
#      6705]
#  [   3585   21607   33591   28922   20733   14154    9990    6962   17100
#      7097]
#  [   8577   50319   87961   85681   67447   49765   36140   27524   72279
#     36133]
#  [   4115   22694   44531   48692   42404   33485   26357   20557   58809
#     35184]]
# Mean absolute deviation (MAD) = 2.5015140210845357
# Mean squared error (MSE) = 33.17114651250509
# Mean absolute percentage error (MAPE) = 110.83517545933009
# Mean squared logarithmic error (MSLE) = 1.2550525854813868
# R^2 Score = 0.09524208551675406
# Cohen kappa score = 0.43920601938509685
# Epoch: 1 | Train Loss: 78.9640
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[298977 114945  22766   7594   2792   1391    774    422    277      4]
#  [ 89193 116066  34246  13436   5229   2643   1244    532    630     23]
#  [ 20995  66383  37876  18192   8927   4180   2456   1195   1140     48]
#  [  6449  28976  28062  18587  10923   6123   3372   1862   2358     75]
#  [  2302  12720  17401  15282  10528   6562   4057   2573   3866    251]
#  [  1234   6731  10610  11200   8867   6348   3963   2936   4774    485]
#  [   540   3945   6257   7634   6964   5479   3666   2832   5374    769]
#  [   418   2819   4055   5131   5102   4558   3393   2559   5650    940]
#  [   989   5860   9407  12727  14523  13262  11784   9692  26651   6301]
#  [   512   2454   4274   5760   7868   8133   7910   7118  21533   6126]]
# Mean absolute deviation (MAD) = 2.1968462724054367
# Mean squared error (MSE) = 50.332510335346704
# Mean absolute percentage error (MAPE) = 93.19255231779874
# Mean squared logarithmic error (MSLE) = 0.9901284207176407
# R^2 Score = 0.1839503539224261
# Cohen kappa score = 0.5506856914667364
# Epoch: 1 | Validation Loss: 61.7979
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1336833  598052  106199   33512   13447    6217    3299    1899    2997
#       548]
#  [ 404803  580651  152247   52641   21878   10699    5734    3332    5390
#      1076]

# %%
with open("experiments_paths.json") as f: 
    experiments_paths = json.load(f)

results_path = "\\result\\results.json"
with open(experiments_paths["tpc"] + results_path) as f: tpc_no_skip_results = json.load(f)
# Out:
#  [ 102332  333777  176157   71910   32951   16839    9157    5363    9485
#      2022]
#  [  32565  150411  143845   77476   40451   22020   12949    8013   14803
#      3497]
#  [  13764   74038   94086   65398   39137   23903   14509    9635   19463
#      5343]
#  [   7280   41304   62084   49857   33101   21654   14413    9666   21726
#      6970]
#  [   4286   25608   42293   37516   26800   18946   12965    8975   21646
#      8405]
#  [   2724   16854   29790   28250   21479   15491   11133    8286   20830
#      8904]
#  [   6235   39128   74476   78000   65358   51947   39810   30680   86860
#     49332]
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1436457  536017   82636   26027   10410    4886    2561    1436    2216
#       357]
#  [ 379506  635292  138502   45164   18634    8803    4716    2683    4335
#       816]
#  [  80616  345957  187691   73725   32218   15966    8647    4833    8642
#      1698]
#  [  23686  136329  151718   85464   44013   24105   13726    8454   15202
#      3333]
#  [   9787   59679   93368   70852   44022   26708   16852   10942   21539
#      5527]
#  [   5047   32018   56553   51696   36770   24654   16925   11488   25167
#      7737]
#  [   2959   19253   36930   36829   28937   21015   14964   10809   26066
#      9678]
#  [   1655   12183   25410   26953   22486   17122   12713    9449   24812
#     10958]
#  [   4052   28310   61017   70684   63932   52816   42526   33845  100940
#     63704]
#  [   2015   13180   29258   37070   36117   32170   26966   22757   75807
#     61488]]
# Mean absolute deviation (MAD) = 2.3138441502692384
# Mean squared error (MSE) = 33.17067251523567
# Mean absolute percentage error (MAPE) = 89.12857899177047
# Mean squared logarithmic error (MSLE) = 0.9737727147396447
# R^2 Score = 0.09525501400509528
# Cohen kappa score = 0.548679185839158
# Epoch: 4 | Train Loss: 61.2671
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[336301  88198  16277   5379   2133    815    489    194    156      0]
#  [ 77103 138319  29640  10476   4159   1787   1012    401    335     10]
#  [ 12357  70734  44336  18477   8197   3727   1839    846    853     26]
#  [  3269  21292  32015  23312  12885   6653   3618   1724   1930     89]
#  [  1216   7103  14819  17442  14064   8743   5071   2770   4040    274]
#  [   618   3353   7458  10683  10462   8561   5850   3480   6142    541]
#  [   260   1792   3913   6261   7099   6385   5202   3892   7762    894]
#  [   171   1216   2607   3993   4777   4671   3952   3589   8160   1489]
#  [   412   2928   5412   8227  11665  12321  12003  11077  35352  11799]
#  [   266    950   2292   3664   5698   6803   7446   7220  26963  10386]]
# Mean absolute deviation (MAD) = 1.9508646271792165
# Mean squared error (MSE) = 46.97970579513316
# Mean absolute percentage error (MAPE) = 73.77870752206282
# Mean squared logarithmic error (MSLE) = 0.7452974938652803
# R^2 Score = 0.2383099505366072
# Cohen kappa score = 0.6499477846880817
# Epoch: 4 | Validation Loss: 46.5169
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.

# %% [markdown]
# #### 3.3.3. results

# %% [markdown]
# **MSLE**

# %%
def plot_no_skip():
    measure = "val_mad"
    plt.bar(["TPC", "TPC (No Skip Connections)"], 
            [tpc_results[measure], tpc_no_skip_results[measure]])
    add_human_baseline(plt, x_cnt=2)
    plt.ylim([0, 4.5])
    plt.title("Average LoS Error")
    plt.show()

# %%
plot_no_skip()

# %% [markdown]
# **Time Performance Analysis**

# %%
plt.bar(["TPC", "TPC (No Skip Connections)"], 
        np.array([time_perf["tpc"], no_skip_time])/60)
plt.title("Execution Time (min)")
# Out:
# Text(0.5, 1.0, 'Execution Time (min)')

# %% [markdown]
# ### 3.4. Adam vs. SGD
# #### 3.4.1. Code Example

# %%
start = time.time()
# !python -m models.run_tpc --model_type tpc --n_epochs {N_EPOCH} --optim SGD
end = time.time()
sgd_time = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "tpc",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "optim": "SGD",
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 3244411895,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1300, 1200, kernel_size=(4,), stride=(1,), dilation=(3,), groups=100)
#       (bn_temp): MyBatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1298, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1469, 1356, kernel_size=(4,), stride=(1,), dilation=(6,), groups=113)
#       (bn_temp): MyBatchNorm1d(1356, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1454, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1638, 1512, kernel_size=(4,), stride=(1,), dilation=(9,), groups=126)
#       (bn_temp): MyBatchNorm1d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1610, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1807, 1668, kernel_size=(4,), stride=(1,), dilation=(12,), groups=139)
#       (bn_temp): MyBatchNorm1d(1668, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1766, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1976, 1824, kernel_size=(4,), stride=(1,), dilation=(15,), groups=152)
#       (bn_temp): MyBatchNorm1d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1922, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(2145, 1980, kernel_size=(4,), stride=(1,), dilation=(18,), groups=165)
#       (bn_temp): MyBatchNorm1d(1980, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2078, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(2314, 2136, kernel_size=(4,), stride=(1,), dilation=(21,), groups=178)
#       (bn_temp): MyBatchNorm1d(2136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2234, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(2483, 2292, kernel_size=(4,), stride=(1,), dilation=(24,), groups=191)
#       (bn_temp): MyBatchNorm1d(2292, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2390, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=2781, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=2781, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[858678 963253 192012  48002  18311   8693   4693   2753   4894   1714]
#  [323894 604164 195254  59206  24745  11878   6551   3734   6937   2088]
#  [129580 351634 160727  57175  25441  12994   7288   4373   8254   2527]
#  [ 58029 210695 126310  50856  23864  12739   7414   4630   8682   2811]
#  [ 29650 132516  97385  43060  21469  11884   7014   4419   8857   3022]
#  [ 16934  88090  74437  36175  19079  10804   6505   4299   8699   3033]
#  [ 10465  60897  58199  30095  16478   9656   6123   3963   8380   3184]
#  [  6377  43865  45429  24996  14458   8551   5422   3615   7851   3177]
#  [ 13700 116412 138341  85776  51518  32600  21343  14684  33121  14331]
#  [  6020  60195  82552  57918  36393  24770  16571  11457  27868  13084]]
# Mean absolute deviation (MAD) = 2.7971041888994908
# Mean squared error (MSE) = 38.0483156077647
# Mean absolute percentage error (MAPE) = 138.3390375593352
# Mean squared logarithmic error (MSLE) = 1.617713895771075
# R^2 Score = -0.037784891333313864
# Cohen kappa score = 0.27574685811951527
# Epoch: 0 | Train Loss: 101.7813
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[184219 171657  64649  20445   6222   1918    559    170     99      4]
#  [ 44416 107975  66966  28115  10333   3663   1223    387    164      0]
#  [  9549  50125  53019  28608  12041   5036   1971    667    376      0]
#  [  2856  21552  35243  24678  12538   5648   2507   1071    688      6]
#  [   947  10319  21445  19560  12154   5927   2804   1271   1096     19]
#  [   528   5803  13888  14438  10707   6062   3118   1343   1225     36]
#  [   309   3323   8952  10512   8582   5578   3224   1525   1405     50]
#  [   264   2084   6358   7436   7022   5053   2867   1593   1876     72]
#  [   520   5209  14697  21025  21973  17679  12196   7298  10150    449]
#  [   223   2109   7137  11700  13626  11576   9215   6281   9244    577]]
# Mean absolute deviation (MAD) = 2.4370576113196565
# Mean squared error (MSE) = 54.51017431695932
# Mean absolute percentage error (MAPE) = 133.14756045741981
# Mean squared logarithmic error (MSLE) = 1.2985525479928404
# R^2 Score = 0.11621716932837545
# Cohen kappa score = 0.42572336927074106
# Epoch: 0 | Validation Loss: 81.0315
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1428897  559209   79705   20481    7325    3252    1513     918    1424
#       279]
#  [ 364237  613881  178341   47075   17059    7671    3893    2175    3448
#       671]
#  [  67772  306507  236027   80443   32701   15270    7855    4515    7337
#      1566]
#  [  18282  114389  178378   91763   44452   22907   12509    7516   12912
#      2922]
#  [   7345   47418  108811   76549   44537   25494   15545    9660   19093
#      4824]
#  [   4195   24771   64344   56011   38069   24120   15785   10707   22908
#      7145]
#  [   2394   14739   40618   39892   30165   20897   14418   10265   24599
#      9453]
#  [   1442    9431   26454   29045   23040   17238   12619    9182   24121
#     11169]
#  [   3473   22760   60902   75924   65571   54536   42081   33141   98186
#     65252]
#  [   1803   11365   27828   41398   36454   32998   27603   22234   72766
#     62379]]
# Mean absolute deviation (MAD) = 2.2923548366498214
# Mean squared error (MSE) = 34.038617590983584
# Mean absolute percentage error (MAPE) = 84.61422721800727
# Mean squared logarithmic error (MSLE) = 0.9242447320014177
# R^2 Score = 0.07158142236955611
# Cohen kappa score = 0.5583461130177011
# Epoch: 4 | Train Loss: 58.1503
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[330519  87436  18420   7862   3346   1359    464    242    278     16]
#  [ 64019 118153  50442  17893   7320   3020   1231    498    617     49]
#  [  7456  38023  57250  32246  14329   6623   2863   1272   1300     30]
#  [  1838   9771  25643  29258  19117  10006   5259   2909   2918     68]
#  [   790   3593   9957  16765  16549  11515   7085   3779   5284    225]
#  [   616   1821   4464   9304  10907   9860   7448   4871   7338    519]
#  [   415   1190   2212   4707   6826   7277   6391   4899   8732    811]
#  [   249    690   1338   3082   4359   5049   5081   4203   9258   1316]
#  [   585   1597   3194   6425  10068  12155  12062  11824  40221  13065]
#  [   338    837   1309   2638   3903   5731   6963   7352  29295  13322]]
# Mean absolute deviation (MAD) = 1.9137734333098069
# Mean squared error (MSE) = 47.18428257287241
# Mean absolute percentage error (MAPE) = 74.76291330672984
# Mean squared logarithmic error (MSLE) = 0.6795372460697217
# R^2 Score = 0.2349931120567158
# Cohen kappa score = 0.6710011337227071
# Epoch: 4 | Validation Loss: 42.4048
# Training complete.
# Experiment ended. Checkpoints stored =)
# Experiment ended.
# 82.70 min

# %%
with open("experiments_paths.json") as f: 
    experiments_paths = json.load(f)

results_path = "\\result\\results.json"
with open(experiments_paths["tpc"] + results_path) as f: tpc_sgd_results = json.load(f)

# %% [markdown]
# #### 3.4.2. Results

# %%
def plot_sgd():
    measure = "val_mad"
    plt.bar(["Adam", "SGD"], 
            [tpc_results[measure], tpc_no_skip_results[measure]])
    add_human_baseline(plt, x_cnt=2)
    plt.ylim([0, 4.5])
    plt.title("Average LoS Error of TPC Model")
    plt.show()

# %%
plot_sgd()

# %% [markdown]
# **Time Performance Analysis**

# %%
plt.bar(["Adam", "SGD"], 
        np.array([time_perf["tpc"], sgd_time])/60)
plt.title("Execution Time (min)")
# Out:
# Text(0.5, 1.0, 'Execution Time (min)')

# %% [markdown]
# ### 3.5. Why multi-tasking shows better performance (Open-ended Question)
# #### 3.5.1. Overview
# > 8.1 Limitations and FutureWork
# </br>
# > ... In futurework, we would like to investigate why the TPC model gains more from the multitask setting than the other models. It seems likely that it is related to additional regularisation provided by the mortality task, but further investigation is needed to confirm our speculations.

# %% [markdown]
# #### 3.5.2. Code Example

# %%
start = time.time()
# !python -m models.run_tpc --model_type tpc --n_epochs {N_EPOCH} --task multitask
end = time.time()
multitask_time = (end - start)
print(f"{(end - start)/60:.2f} min")
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/multitask/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
#     "model_type": "tpc",
#     "n_epochs": 5,
#     "n_layers": 9,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 12,
#     "optim": "Adam",
#     "percentage_data": 100.0,
#     "point_size": 13,
#     "point_sizes": [
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13,
#         13
#     ],
#     "save_results_csv": false,
#     "seed": 3878430477,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "multitask",
#     "temp_dropout_rate": 0.05,
#     "temp_kernels": [
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12,
#         12
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.45, inplace=False)
#   (temp_dropout): Dropout(p=0.05, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=64, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=17, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=17, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (temp): Conv1d(174, 1044, kernel_size=(4,), stride=(1,), groups=87)
#       (bn_temp): MyBatchNorm1d(1044, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=241, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ModuleDict(
#       (temp): Conv1d(1300, 1200, kernel_size=(4,), stride=(1,), dilation=(3,), groups=100)
#       (bn_temp): MyBatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1298, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ModuleDict(
#       (temp): Conv1d(1469, 1356, kernel_size=(4,), stride=(1,), dilation=(6,), groups=113)
#       (bn_temp): MyBatchNorm1d(1356, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1454, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ModuleDict(
#       (temp): Conv1d(1638, 1512, kernel_size=(4,), stride=(1,), dilation=(9,), groups=126)
#       (bn_temp): MyBatchNorm1d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1610, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ModuleDict(
#       (temp): Conv1d(1807, 1668, kernel_size=(4,), stride=(1,), dilation=(12,), groups=139)
#       (bn_temp): MyBatchNorm1d(1668, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1766, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ModuleDict(
#       (temp): Conv1d(1976, 1824, kernel_size=(4,), stride=(1,), dilation=(15,), groups=152)
#       (bn_temp): MyBatchNorm1d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1922, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ModuleDict(
#       (temp): Conv1d(2145, 1980, kernel_size=(4,), stride=(1,), dilation=(18,), groups=165)
#       (bn_temp): MyBatchNorm1d(1980, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2078, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ModuleDict(
#       (temp): Conv1d(2314, 2136, kernel_size=(4,), stride=(1,), dilation=(21,), groups=178)
#       (bn_temp): MyBatchNorm1d(2136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2234, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 85.13 min
#     )
#     (8): ModuleDict(
#       (temp): Conv1d(2483, 2292, kernel_size=(4,), stride=(1,), dilation=(24,), groups=191)
#       (bn_temp): MyBatchNorm1d(2292, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=2390, out_features=13, bias=True)
#       (bn_point): MyBatchNorm1d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (point_last_los): Linear(in_features=2781, out_features=17, bias=True)
#   (point_last_mort): Linear(in_features=2781, out_features=17, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1170893  710063  139661   44593   17782    8230    4323    2404    4059
#       995]
#  [ 396858  539292  173501   66080   28617   13736    7658    4244    6957
#      1508]
#  [ 128626  314086  162584   73488   34791   18195   10098    5869   10087
#      2169]
#  [  49709  169730  126396   69199   36294   20055   11739    7126   12832
#      2950]
#  [  23417   97444   89449   57364   33063   19991   12175    7831   14834
#      3708]
#  [  13156   60265   63313   44991   28721   18004   11661    7600   15992
#      4352]
#  [   7878   39098   46113   36097   23904   16018   10382    7231   15635
#      5084]
#  [   4807   26203   34309   28465   19904   13776    9490    6622   14916
#      5249]
#  [  10226   65700   95840   86521   66255   47599   34611   25030   62819
#     27225]
#  [   4999   33905   52200   52180   42731   33100   24736   18720   49884
#     24373]]
# Mean absolute deviation (MAD) = 2.5637723912644472
# Mean squared error (MSE) = 34.05552153694157
# Mean absolute percentage error (MAPE) = 115.03048678418153
# Mean squared logarithmic error (MSLE) = 1.3252782941662304
# R^2 Score = 0.07112035965393004
# Cohen kappa score = 0.3998744429415063
# ==> Mortality:
# Confusion matrix:
# [[59533   688]
#  [ 5870   824]]
# Accuracy = 0.901995062828064
# Precision Survived = 0.9102487564086914
# Precision Died = 0.5449735522270203
# Recall Survived = 0.9885753989219666
# Recall Died = 0.1230953112244606
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8121972748449445
# Area Under the Precision Recall curve (AUPRC) = 0.36150215492925253
# F1 score (macro averaged) = 0.5743126306652914
# Epoch: 0 | Train Loss: 102.9760
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[283106 112486  33998  12336   4495   2024    852    345    297      3]
#  [ 59996 109480  53144  22635   9738   4356   2011    922    938     22]
#  [  8589  44521  48089  29481  14586   7625   4057   2162   2157    125]
#  [  2368  14680  26112  24364  16601   9525   5600   3148   4190    199]
#  [   907   5995  12326  15811  14400   9901   6426   3878   5578    320]
#  [   587   3139   7007   9804  10471   8669   6294   4166   6629    382]
#  [   358   1694   4033   6129   7052   6854   5642   3923   7237    538]
#  [   225   1048   2597   4358   4716   4932   4805   3601   7631    712]
#  [   436   2424   5854   8797  11628  13384  14118  12790  36221   5544]
#  [   349   1089   2134   3758   5472   6825   7768   7857  28946   7490]]
# Mean absolute deviation (MAD) = 2.083583727775206
# Mean squared error (MSE) = 48.79530199672858
# Mean absolute percentage error (MAPE) = 98.53975874013015
# Mean squared logarithmic error (MSLE) = 0.9055334040402256
# R^2 Score = 0.20887337708020148
# Cohen kappa score = 0.5995344124997477
# ==> Mortality:
# Confusion matrix:
# [[12902    62]
#  [ 1189   158]]
# Accuracy = 0.9125847220420837
# Precision Survived = 0.9156199097633362
# Precision Died = 0.7181817889213562
# Recall Survived = 0.995217502117157
# Recall Died = 0.1172977015376091
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8558604525764569
# Area Under the Precision Recall curve (AUPRC) = 0.43585326240984834
# F1 score (macro averaged) = 0.5777100394773604
# Epoch: 0 | Validation Loss: 72.1684
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1473985  497055   87241   25755    9380    4163    2122    1144    1842
#       316]
#  [ 387613  578610  173411   55376   21009    9623    4949    2823    4307
#       730]
#  [  78487  300300  212793   87086   37409   18165    9597    5440    9094
#      1622]
#  [  22246  117476  158479   92630   47512   25843   14508    8684   15488
#      3164]
#  [   9231   50426   95606   75089   46256   27920   17339   11089   21107
#      5213]
#  [   5185   25896   57728   54018   38769   25654   17075   11735   24843
#      7152]
#  [   3024   15222   35941   38440   30488   22010   15641   11367   26324
#      8983]
#  [   1883    9293   24226   27642   23141   18171   13355   10039   25801
#     10190]
#  [   4891   21298   56201   71550   66299   55216   44481   35448  105771
#     60671]
#  [   2427   10529   27985   37981   38426   34007   28906   23979   77871
#     54717]]
# Mean absolute deviation (MAD) = 2.264527399729345
# Mean squared error (MSE) = 31.51263997259103
# Mean absolute percentage error (MAPE) = 85.01054943332186
# Mean squared logarithmic error (MSLE) = 0.925304560174118
# R^2 Score = 0.14047859603784163
# Cohen kappa score = 0.5565144913003185
# ==> Mortality:
# Confusion matrix:
# [[59769   452]
#  [ 5704   990]]
# Accuracy = 0.9080026745796204
# Precision Survived = 0.9128801226615906
# Precision Died = 0.6865464448928833
# Recall Survived = 0.9924942851066589
# Recall Died = 0.14789363741874695
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8433338917121855
# Area Under the Precision Recall curve (AUPRC) = 0.4402279290020863
# F1 score (macro averaged) = 0.5971933735405454
# Epoch: 1 | Train Loss: 75.1018
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[310886 104423  22341   7055   2740   1210    561    313    407      6]
#  [ 50971 135353  48008  16704   6672   2830   1354    654    666     30]
#  [  5273  49986  53635  26975  12862   6439   3137   1610   1430     45]
#  [  1486  14225  28870  24681  15918   9518   5394   3201   3369    125]
#  [   663   5070  12612  15990  14000   9948   6711   4583   5695    270]
#  [   508   2471   6386   9018  10269   8611   6726   4756   7859    544]
#  [   245   1301   3515   4925   6226   6653   5930   4600   9306    759]
#  [   171    794   2165   3309   3859   4587   4472   3969  10212   1087]
#  [   393   1620   4313   7018   8569  10300  11053  10916  42416  14598]
#  [   302    892   1526   2265   3754   4876   5862   6381  29831  15999]]
# Mean absolute deviation (MAD) = 1.9213883458773016
# Mean squared error (MSE) = 47.451696048407996
# Mean absolute percentage error (MAPE) = 79.12039682197316
# Mean squared logarithmic error (MSLE) = 0.7078231822588745
# R^2 Score = 0.23065749138901503
# Cohen kappa score = 0.6639723966482713
# ==> Mortality:
# Confusion matrix:
# [[12915    49]
#  [ 1184   163]]
# Accuracy = 0.913842499256134
# Precision Survived = 0.9160224199295044
# Precision Died = 0.7688679099082947
# Recall Survived = 0.9962202906608582
# Recall Died = 0.12100964784622192
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8584355695069689
# Area Under the Precision Recall curve (AUPRC) = 0.46439301601502403
# F1 score (macro averaged) = 0.5817740218301832
# Epoch: 1 | Validation Loss: 59.1750
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1541511  459948   67730   19329    7173    3248    1581     840    1421
#       222]
#  [ 351503  638425  164341   47902   17853    7918    4159    2216    3499
#       635]
#  [  58259  309352  228666   87847   36117   17051    8697    4891    7705
#      1408]
#  [  15929  105054  167699   99739   50978   26015   14757    8617   14456
#      2786]
#  [   6886   40842   94585   79446   50375   30444   18377   11653   21826
#      4842]
#  [   3894   20347   52337   55658   41407   28076   19025   12913   27314
#      7084]
#  [   2143   11285   31550   38013   31716   23729   17190   12838   29609
#      9367]
#  [   1256    6747   20347   26179   23701   19272   14765   10990   29101
#     11383]
#  [   3551   15169   45043   62512   62710   55417   46589   37774  119531
#     73530]
#  [   1926    7184   20962   31133   34027   32454   28513   24510   86700
#     69419]]
# Mean absolute deviation (MAD) = 2.162130928191098
# Mean squared error (MSE) = 30.66684271483474
# Mean absolute percentage error (MAPE) = 75.91379411270655
# Mean squared logarithmic error (MSLE) = 0.8037831339220983
# R^2 Score = 0.16354809599361608
# Cohen kappa score = 0.6012851752382953
# ==> Mortality:
# Confusion matrix:
# [[59754   467]
#  [ 5567  1127]]
# Accuracy = 0.9098259210586548
# Precision Survived = 0.9147747159004211
# Precision Died = 0.7070263624191284
# Recall Survived = 0.9922452569007874
# Recall Died = 0.16835972666740417
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8504754636278038
# Area Under the Precision Recall curve (AUPRC) = 0.4626354353435187
# F1 score (macro averaged) = 0.6119479316063926
# Epoch: 2 | Train Loss: 66.7740
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[337059  90387  15894   4284   1398    470    212    128    109      1]
#  [ 49359 145981  46584  13953   4454   1620    654    309    327      1]
#  [  4477  50351  58251  27675  11412   4936   2334   1078    878      0]
#  [  1551  13121  30454  26888  15781   8972   4686   2520   2751     63]
#  [   732   5162  12531  16417  13933   9951   6785   4196   5672    163]
#  [   524   2693   6330   9058   9720   7939   6909   4884   8612    479]
#  [   240   1541   3550   5173   5674   5618   5369   4848  10504    943]
#  [   204    778   2111   3443   3691   3844   3916   3836  11327   1475]
#  [   574   2116   4692   6532   7915   8324   9034   9704  44964  17341]
#  [   316    756   1825   2702   3369   4024   4754   5056  29388  19498]]
# Mean absolute deviation (MAD) = 1.8157638224821027
# Mean squared error (MSE) = 45.895575893805876
# Mean absolute percentage error (MAPE) = 64.77629902561065
# Mean squared logarithmic error (MSLE) = 0.5895049846801166
# R^2 Score = 0.25588713507172756
# Cohen kappa score = 0.692548397810095
# ==> Mortality:
# Confusion matrix:
# [[12883    81]
#  [ 1114   233]]
# Accuracy = 0.9164978265762329
# Precision Survived = 0.9204115271568298
# Precision Died = 0.7420381903648376
# Recall Survived = 0.9937519431114197
# Recall Died = 0.17297698557376862
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8628755961056682
# Area Under the Precision Recall curve (AUPRC) = 0.47595541711492445
# F1 score (macro averaged) = 0.6181153007127539
# Epoch: 2 | Validation Loss: 51.5720
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1585055  433470   56117   16412    5922    2649    1303     725    1168
#       182]
#  [ 319804  683279  159512   44197   15918    6981    3528    1840    2905
#       487]
#  [  44966  308307  244262   90123   35461   16003    8157    4463    7064
#      1187]
#  [  12316   93918  174233  106573   52652   27121   14557    8406   13690
#      2564]
#  [   5385   34435   92934   83960   53301   31968   19189   12053   21489
#      4562]
#  [   3219   16724   49648   56363   43347   30059   19985   13658   28092
#      6960]
#  [   1838    9189   28903   37065   32707   25083   18408   13294   31397
#      9556]
#  [   1001    5605   17814   24957   24044   19969   15263   11764   31178
#     12146]
#  [   2869   11852   38375   57096   60804   55100   47201   39737  128100
#     80692]
#  [   1498    5517   17097   27722   32100   31019   28309   24611   90653
#     78302]]
# Mean absolute deviation (MAD) = 2.092747550014293
# Mean squared error (MSE) = 30.0252984515732
# Mean absolute percentage error (MAPE) = 69.89528807820366
# Mean squared logarithmic error (MSLE) = 0.7233902490228131
# R^2 Score = 0.18104650381796983
# Cohen kappa score = 0.6284766867518419
# ==> Mortality:
# Confusion matrix:
# [[59756   465]
#  [ 5489  1205]]
# Accuracy = 0.9110214710235596
# Precision Survived = 0.9158709645271301
# Precision Died = 0.7215569019317627
# Recall Survived = 0.9922784566879272
# Recall Died = 0.18001195788383484
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8582449599656305
# Area Under the Precision Recall curve (AUPRC) = 0.4761281092734523
# F1 score (macro averaged) = 0.6203422793341486
# Epoch: 3 | Train Loss: 61.2815
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[362450  69644  11525   3857   1473    554    174    137    127      1]
#  [ 58160 147120  39193  11364   4274   1775    686    290    366     14]
#  [  5169  50921  57700  27130  11205   4819   2377   1078    977     16]
#  [  1538  12127  28315  28197  17077   9054   4608   2722   3109     40]
#  [   673   4189  11350  15819  14661  10830   7300   4293   6234    193]
#  [   442   2191   5385   8657   9195   8519   7210   5508   9422    619]
#  [   199   1137   2848   4786   5199   5703   5519   4903  11993   1173]
#  [   182    597   1573   2890   3491   3686   3744   3808  12864   1790]
#  [   424   1499   3423   5778   6923   7795   8310   8970  47187  20887]
#  [   290    642   1399   2236   3051   3579   4064   4458  28865  23104]]
# Mean absolute deviation (MAD) = 1.7617149064217401
# Mean squared error (MSE) = 45.28117443574063
# Mean absolute percentage error (MAPE) = 58.32640817025696
# Mean squared logarithmic error (MSLE) = 0.5197292885323249
# R^2 Score = 0.2658485315739717
# Cohen kappa score = 0.7163065663002857
# ==> Mortality:
# Confusion matrix:
# [[12862   102]
#  [ 1076   271]]
# Accuracy = 0.9176856875419617
# Precision Survived = 0.9228009581565857
# Precision Died = 0.7265415787696838
# Recall Survived = 0.9921320676803589
# Recall Died = 0.20118781924247742
# Area Under the Receiver Operating Characteristic curve (AUROC) = 0.8657139054710812
# Area Under the Precision Recall curve (AUPRC) = 0.4786678049646931
# F1 score (macro averaged) = 0.6356638565819435
# Epoch: 3 | Validation Loss: 47.5097
# Train Metrics:
# ==> Length of Stay:

# %%
with open("experiments_paths.json") as f: 
    experiments_paths = json.load(f)

results_path = "\\result\\results.json"
with open(experiments_paths["tpc"] + results_path) as f: tpc_multitask_results = json.load(f)
with open(experiments_paths["tpc"] + results_log_path) as f: tpc_multitask_results_log = json5.load(f)

# %%
def plot_multitask():    
    measure = "val_mad"
    plt.bar(["LoS Only", "Multitask"], 
            [tpc_results[measure], tpc_multitask_results[measure]])
    
    print(f"LoS Only: {tpc_results[measure]:.2f}")
    print(f"Multitask: {tpc_multitask_results[measure]:.2f}")
    
    add_human_baseline(plt, x_cnt=2)
    plt.ylim([0, 4.5])
    plt.title("Average LoS Error of TPC Model")
    plt.show()

# %%
plot_multitask()
# Out:
# LoS Only: 1.74
# Multitask: 1.69

# %%
def add_loss_plot(results_log, measure, label, linestyle='k-'):
    l = []
    for d in results_log:
        if measure in d:
            # print(d[measure])  # Uncomment to check whether list is correct or not
            l.append(d[measure]['data'])

    plt.plot(l, linestyle, label=label)

# %%
add_loss_plot(results_log=tpc_multitask_results_log, 
              measure="train_msle", 
              label="Training Loss (Multitask)",
              linestyle='k--')

add_loss_plot(results_log=tpc_multitask_results_log, 
              measure="val_msle", 
              label="Validation Loss (Multitask)",
              linestyle='r--')

plt.legend()
plt.show()

# %% [markdown]
# **Time Performance Analysis**

# %%
plt.bar(["LoS Only", "Multitask"], 
        np.array([time_perf["tpc"], multitask_time])/60)
plt.title("Execution Time (min)")
# Out:
# Text(0.5, 1.0, 'Execution Time (min)')

# %% [markdown]
# ## 4. Summary of the Key Results

# %% [markdown]
# ### 4.1 TPC is better than the other models

# %%
plot_msle()

# %% [markdown]
# ### 4.2 MSLE is better loss function than MSE

# %%
msle_mle_comp()

# %% [markdown]
# ### 4.3 Skip connection makes the TPC model better

# %%
plot_no_skip()

# %% [markdown]
# ### 4.4 Adam is better optimizer than SGD

# %%
plot_sgd()

# %% [markdown]
# ## References
#  - https://dl.acm.org/doi/10.1145/3450439.3451860
#  - https://github.com/EmmaRocheteau/TPC-LoS-prediction
#  - https://github.com/EmmaRocheteau/MIMIC-IV-Postgres
#  - https://github.com/MIT-LCP/mimic-code/
#  - https://github.com/MIT-LCP/mimic-iv/

# %%
total_end = time.time()
print(f"Total Notebook Time: {(total_end - total_start)/60:.2f} min")
# Out:
# Total Notebook Time: 759.30 min
